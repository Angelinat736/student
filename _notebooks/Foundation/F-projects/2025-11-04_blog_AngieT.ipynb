# %% [markdown]
# ---
# layout: post
# title: Im Angie Tuchinskaya
# permalink: /myblog2
# ---

# %% [markdown]
#    Hi! My name is Angie Tuchinskaya
#
#
#
#
#
# ### Something to compare yourself to from the beginning of the year to how you are now
# I didnt really know anything about coding,and now I have some knowledge about it, and i understand it more. We had to learn tools anjd it was hard , but now I can use the tools more easily
#
# ### Three things from 3 sprints
# ### Sprint 1-
# Tools setup like VScode, github and make
# develope code and make
# Commit and pull
# I made a blog on VScode and commited it.
#
# ### Sprint 2-
# Variables
# Booleans
# Strings
# I did the homework from diffrent groups that was about strings, booleans and variables.
#
# ### Sprint 3-
# The mansion game
# me and my group made a gambling room/ casino in the Mansion game. We were able to get in the website and make sprites that was interactive. The game we made was BlackJack.
#
# ### How did N@tM go?
# N@tM went reall well, a lot of people complimented our gambling game thay were saying that it was really fun and creative. Alot of them wanted to play the game multiple times.
#
# ### What do you want to do on the next project, given time?
# Probably making another game or a website.
#
# ### What do you want to learn next in Comp Sci?
# The next thing I want to learn in Comp Sci is probably building a website or app
#
# ### Analytics review
# https://drive.google.com/file/d/1apxffju7inHuIXyz_WGejqksufSOd94R/view?usp=sharing
